# %%
import numpy as np
import pandas as pd
import os
import csv

# %%
# read food_data.csv into dataframe
ffile = "raw_data/RDC_InventoryCoreMetrics_Zip_Hist.csv"
# define lambda function to parse date column
# dateparse = lambda x: pd.datetime.strptime(x, '%Y-%m')
# fdf = pd.read_csv(ffile, parse_dates=['Month'], date_parser=dateparse)
fdf = pd.read_csv(ffile)
fdf.head()
# Out:
#         Month  ZipCode          ZipName Footnote  Median Listing Price  \
# 0  2017-09-01   1001.0       Agawam, MA      NaN              213700.0
# 1  2017-09-01   1002.0      Amherst, MA      NaN              358500.0
# 2  2017-09-01   1005.0        Barre, MA      NaN              251300.0
# 3  2017-09-01   1007.0  Belchertown, MA      NaN              333600.0
# 4  2017-09-01   1008.0    Blandford, MA      NaN              186200.0
#
#    Median Listing Price M/M  Median Listing Price Y/Y  Active Listing Count   \
# 0                   -0.0387                   -0.0286                   52.0
# 1                   -0.0465                    0.0913                  110.0
# 2                   -0.0408                    0.1100                   24.0
# 3                   -0.0039                    0.1120                   82.0
# 4                    0.0081                   -0.0432                   14.0
#
#    Active Listing Count M/M  Active Listing Count Y/Y        ...          \
# ...

# %%
fdf = fdf.loc[fdf['ZipName'].isin(["Austin, TX"])]

# %%
fdf
# Out:
#              Month  ZipCode     ZipName Footnote  Median Listing Price  \
# 12304   2017-09-01  78701.0  Austin, TX        *              573400.0
# 12305   2017-09-01  78702.0  Austin, TX      NaN              435000.0
# 12306   2017-09-01  78703.0  Austin, TX      NaN              937500.0
# 12307   2017-09-01  78704.0  Austin, TX      NaN              599000.0
# 12308   2017-09-01  78705.0  Austin, TX        *              349000.0
# 12309   2017-09-01  78717.0  Austin, TX      NaN              363300.0
# 12310   2017-09-01  78721.0  Austin, TX        *              366500.0
# 12311   2017-09-01  78723.0  Austin, TX      NaN              413700.0
# 12312   2017-09-01  78726.0  Austin, TX      NaN              494500.0
# 12313   2017-09-01  78727.0  Austin, TX      NaN              344100.0
# 12314   2017-09-01  78729.0  Austin, TX      NaN              329400.0
# 12315   2017-09-01  78730.0  Austin, TX      NaN              798500.0
# ...

# %%
list(fdf)
# Out:
# ['Month',
#  'ZipCode',
#  'ZipName',
#  'Median Listing Price',
#  'Median Listing Price M/M',
#  'Median Listing Price Y/Y',
#  'Active Listing Count ',
#  'Active Listing Count M/M',
#  'Active Listing Count Y/Y',
#  'Days on Market ',
#  'Days on Market M/M',
#  'Days on Market Y/Y',
#  'New Listing Count ',
#  'New Listing Count M/M',
#  'New Listing Count Y/Y',
#  'Price Increase Count ',
#  'Price Increase Count M/M',
#  'Price Increase Count Y/Y',
#  'Price Decrease Count ',
#  'Price Decrease Count M/M',
#  'Price Decrease Count Y/Y',
#  'Pending Listing Count ',
#  'Pending Listing Count M/M',
#  'Pending Listing Count Y/Y',
#  'Avg Listing Price',
#  'Avg Listing Price M/M',
#  'Avg Listing Price Y/Y',
#  'Total Listing Count',
#  'Total Listing Count M/M',
#  'Total Listing Count Y/Y',
#  'Pending Ratio',
#  'Pending Ratio M/M',
#  'Pending Ratio Y/Y']

# %%
fdf.dtypes
# Out:
# Month                         object
# ZipCode                      float64
# ZipName                       object
# Median Listing Price         float64
# Median Listing Price M/M     float64
# Median Listing Price Y/Y     float64
# Active Listing Count         float64
# Active Listing Count M/M     float64
# Active Listing Count Y/Y     float64
# Days on Market               float64
# Days on Market M/M           float64
# Days on Market Y/Y           float64
# New Listing Count            float64
# New Listing Count M/M        float64
# New Listing Count Y/Y        float64
# Price Increase Count         float64
# Price Increase Count M/M     float64
# Price Increase Count Y/Y     float64
# Price Decrease Count         float64
# Price Decrease Count M/M     float64
# Price Decrease Count Y/Y     float64
# Pending Listing Count        float64
# Pending Listing Count M/M    float64
# Pending Listing Count Y/Y    float64
# Avg Listing Price            float64
# ...

# %%
columns = ['Footnote']
fdf.drop(columns, inplace=True, axis=1)
fdf
# Out:
#              Month  ZipCode     ZipName  Median Listing Price  \
# 12304   2017-09-01  78701.0  Austin, TX              573400.0
# 12305   2017-09-01  78702.0  Austin, TX              435000.0
# 12306   2017-09-01  78703.0  Austin, TX              937500.0
# 12307   2017-09-01  78704.0  Austin, TX              599000.0
# 12308   2017-09-01  78705.0  Austin, TX              349000.0
# 12309   2017-09-01  78717.0  Austin, TX              363300.0
# 12310   2017-09-01  78721.0  Austin, TX              366500.0
# 12311   2017-09-01  78723.0  Austin, TX              413700.0
# 12312   2017-09-01  78726.0  Austin, TX              494500.0
# 12313   2017-09-01  78727.0  Austin, TX              344100.0
# 12314   2017-09-01  78729.0  Austin, TX              329400.0
# 12315   2017-09-01  78730.0  Austin, TX              798500.0
# 12316   2017-09-01  78731.0  Austin, TX              749500.0
# 12317   2017-09-01  78732.0  Austin, TX              601200.0
# ...

# %%
fdf.to_csv("raw_data/austin_real_estate.csv",header=True,index=False)
